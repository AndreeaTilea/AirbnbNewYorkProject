# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\Users\tilea\Downloads\AB_NYC_2019 - AB_NYC_2019.csv')

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.dtypes
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
# removing duplicates
df.duplicated().sum()
df.drop_duplicates(inplace = True)

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# drop the unnecessary columns

df.drop(['name', 'id', 'host_name', 'last_review'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    host_id neighbourhood_group neighbourhood  latitude  longitude  \
# 0     2787            Brooklyn    Kensington  40.64749  -73.97237
# 1     2845           Manhattan       Midtown  40.75362  -73.98377
# 2     4632           Manhattan        Harlem  40.80902  -73.94190
# 3     4869            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4     7192           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# 1  Entire home/apt    225               1                 45
# 2     Private room    150               3                  0
# 3  Entire home/apt     89               1                270
# 4  Entire home/apt     80              10                  9
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# ...

# %%
# replacing the reviews_per_month by 0

df.fillna({'reviews_per_month':0}, inplace=True)

# %%
# checking to see if it worked

df.reviews_per_month.isnull().sum()
# Out:
# 0

# %%
# Removing the NaN values from the dataset

df.isnull().sum
df.dropna(how='any', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48895 entries, 0 to 48894
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   host_id                         48895 non-null  int64
#  1   neighbourhood_group             48895 non-null  object
#  2   neighbourhood                   48895 non-null  object
#  3   latitude                        48895 non-null  float64
#  4   longitude                       48895 non-null  float64
#  5   room_type                       48895 non-null  object
#  6   price                           48895 non-null  int64
#  7   minimum_nights                  48895 non-null  int64
#  8   number_of_reviews               48895 non-null  int64
#  9   reviews_per_month               48895 non-null  float64
#  10  calculated_host_listings_count  48895 non-null  int64
#  11  availability_365                48895 non-null  int64
# ...

# %%
# examine the continous variables

df.describe()
# Out:
#             host_id      latitude     longitude         price  minimum_nights  \
# count  4.889500e+04  48895.000000  48895.000000  48895.000000    48895.000000
# mean   6.762001e+07     40.728949    -73.952170    152.720687        7.029962
# std    7.861097e+07      0.054530      0.046157    240.154170       20.510550
# min    2.438000e+03     40.499790    -74.244420      0.000000        1.000000
# 25%    7.822033e+06     40.690100    -73.983070     69.000000        1.000000
# 50%    3.079382e+07     40.723070    -73.955680    106.000000        3.000000
# 75%    1.074344e+08     40.763115    -73.936275    175.000000        5.000000
# max    2.743213e+08     40.913060    -73.712990  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       48895.000000       48895.000000                    48895.000000
# mean           23.274466           1.090910                        7.143982
# ...

# %%
df.columns
# Out:
# Index(['host_id', 'neighbourhood_group', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
# finding correlation between different variables

corr = df.corr(method='kendall')
plt.figure(figsize=(15,8))
sns.heatmap(corr, annot=True)
df.columns
# Out:
# Index(['host_id', 'neighbourhood_group', 'neighbourhood', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
df.head()
# Out:
#    host_id neighbourhood_group neighbourhood  latitude  longitude  \
# 0     2787            Brooklyn    Kensington  40.64749  -73.97237
# 1     2845           Manhattan       Midtown  40.75362  -73.98377
# 2     4632           Manhattan        Harlem  40.80902  -73.94190
# 3     4869            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4     7192           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# 1  Entire home/apt    225               1                 45
# 2     Private room    150               3                  0
# 3  Entire home/apt     89               1                270
# 4  Entire home/apt     80              10                  9
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# ...

# %%
df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
# Visualizing the data from the airbnb neighbourhood group

sns.countplot(df['neighbourhood_group'], palette="rocket")
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Neighbourhood Group')
# Out:
# Text(0.5, 1.0, 'Neighbourhood Group')

# %%
# Visualizing the Neighbournhood
sns.countplot(df['neighbourhood'], palette="rocket")
fig = plt.gcf()
fig.set_size_inches(26,8)
plt.title('Neighbourhood')
# Out:
# Text(0.5, 1.0, 'Neighbourhood')

# %%
# Visualizing room type

sns.countplot(df['room_type'], palette="rocket")
fig = plt.gcf()
fig.set_size_inches(8,8)
plt.title('Room Type')
# Out:
# Text(0.5, 1.0, 'Room Type')

# %%
# relationship between the Neighbourhood and the Room Type

sns.boxplot(x='neighbourhood_group',y='availability_365', palette="rocket", data=df)
plt.title("Avalabilty of Room Based on Neighbourhood")
# Out:
# Text(0.5, 1.0, 'Avalabilty of Room Based on Neighbourhood')

# %%
# Map of the Neighbourhood Group
plt.figure(figsize=(12,8))
sns.scatterplot(df.longitude,df.latitude,hue=df.neighbourhood_group)
plt.ioff()
plt.title("Map Of The Neighbourhood Group")
# Out:
# Text(0.5, 1.0, 'Map Of The Neighbourhood Group')

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(df.longitude,df.latitude,hue=df.neighbourhood)
plt.ioff()
plt.title("Map Of The Neighbourhood")
# Out:
# Text(0.5, 1.0, 'Map Of The Neighbourhood')

# %%
# Map of Room Type

plt.figure(figsize=(12,8))
sns.scatterplot(df.longitude,df.latitude,hue=df.room_type)
plt.ioff()
plt.title("Room Type")
# Out:
# Text(0.5, 1.0, 'Room Type')

# %%
# Avalability of Room in the Neighbourhood
plt.figure(figsize=(10,6))
sns.scatterplot(df.longitude,df.latitude,hue=df.availability_365)
plt.ioff()
plt.title("Room Avalability")
# Out:
# Text(0.5, 1.0, 'Room Avalability')

# %%
# Dropping unecessarry columns

df.drop(['host_id','latitude','longitude','neighbourhood','number_of_reviews','reviews_per_month'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14144/12615347.py in <module>
#       1 # Dropping unecessarry columns
#       2
# ----> 3 df.drop(['host_id','latitude','longitude','neighbourhood','number_of_reviews','reviews_per_month'], axis=1, inplace=True)
#       4 df.head()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ...

# %%
df.head()
# Out:
#   neighbourhood_group        room_type  price  minimum_nights  \
# 0            Brooklyn     Private room    149               1
# 1           Manhattan  Entire home/apt    225               1
# 2           Manhattan     Private room    150               3
# 3            Brooklyn  Entire home/apt     89               1
# 4           Manhattan  Entire home/apt     80              10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %%
def Encode(df):
    for column in df.columns[df.columns.isin(['neighbourhood_group', 'room_type'])]:
        df[column] = df[column].factorize()[0]
    return df

airbnb = Encode(df.copy())

# %%
airbnb.head()
# Out:
#    neighbourhood_group  room_type  price  minimum_nights  \
# 0                    0          0    149               1
# 1                    1          1    225               1
# 2                    1          0    150               3
# 3                    0          1     89               1
# 4                    1          1     80              10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %%
# Looking at corellation between the variables
corr = airbnb.corr(method='kendall')
plt.figure(figsize=(18,12))
sns.heatmap(corr, annot=True)
airbnb.columns
# Out:
# Index(['neighbourhood_group', 'room_type', 'price', 'minimum_nights',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
# The room type and price have a high correlation
